# %% [markdown]
# ### Model adaptation to multi-GPU training

# %%
import torch
import sys
import re
import torch.nn as nn
from torch.nn import DataParallel
# from torch.nn import TransformerDecoder, TransformerDecoderLayer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if device.type == 'cpu':
    file_path = './kaggleData/data/eng-cmn.txt'
else:
    file_path = '/kaggle/input/eng-cmn/eng-cmn.txt'
    sys.path.append('/kaggle/input/eng-cmn')


text_pairs = []
with open(file_path, 'r', encoding='utf-8') as f:
    for line in f:

        parts = line.strip().split('\t')
        

        if len(parts) < 3:
            continue
            
        en_text = parts[0].strip()
        zh_text = parts[1].strip()
        

        if en_text and zh_text:

            text_pairs.append((zh_text, en_text))

def split_chinese_english(s):

    pattern = re.compile(r'([\u4e00-\u9fff]+)|([^\u4e00-\u9fff]+)')
    result = []
    for block in pattern.findall(s):
        chinese_part, non_chinese_part = block
        if chinese_part:
            
            result.extend(list(chinese_part))
        elif non_chinese_part:

            subparts = non_chinese_part.lower().split()
            for sub in subparts:

                processed = re.sub(r'[^a-zA-Z]', '', sub)
                if processed:
                    result.append(processed)
    return result

# %%
from collections import defaultdict

def build_vocab(text_pairs, unknown = True):
    '''
    text_pairs: raw cn-eng text pair
    unknown: whether to deal with unkonwn words
    '''
    vocab = defaultdict(lambda: len(vocab))
    special_tokens = ["<pad>", "<sos>", "<eos>", "<sep>"]
    for token in special_tokens:
        vocab[token]

    for ch, en in text_pairs:
        ch = split_chinese_english(ch)
        for char in ch:
            vocab[char]
        en = split_chinese_english(en)
        for char in en:
            vocab[char]
    # add <unk> to the las of the vocab to deal with unknown words
    if unknown:    
        vocab['<unk>']
    
    # freeze vocab (check usage of 'defaultdict')
    vocab.default_factory = None
    
    return vocab

def text_to_ids(text, vocab):
    unk_id = vocab['<unk>']
    split = split_chinese_english(text)
    # print(split)
    ids = [vocab.get(id, unk_id) for id in split]
    return ids

# %%
# build vocab
vocab = build_vocab(text_pairs)
len(vocab)
# Out:
# 10738

# %%
# build dataset

from torch.utils.data import Dataset, DataLoader

class TranslationDataset(Dataset):
    def __init__(self, pairs, vocab, max_len=50):
        self.pairs = pairs
        self.vocab = vocab
        self.max_len = max_len

    def __len__(self):
        return len(self.pairs)

    def __getitem__(self, idx):
        ch, en = self.pairs[idx]

        input_ids_cn_eng = (
            [self.vocab["<sos>"]] +
            text_to_ids(ch, self.vocab) +
            [self.vocab["<sep>"]] +
            text_to_ids(en, self.vocab) +
            [self.vocab["<eos>"]]
        )

        input_ids_cn_eng = input_ids_cn_eng[:self.max_len]
        src = input_ids_cn_eng[:-1]
        tgt = input_ids_cn_eng[1:]

        # pad to max_len
        # ================================================================
        src += [self.vocab["<pad>"]]* (self.max_len - len(src))
        tgt += [self.vocab["<pad>"]]* (self.max_len - len(tgt))
        # ================================================================

        return torch.tensor(src), torch.tensor(tgt)

# %%
# hyper params

vocab_size = len(vocab)
eval_num = 100
BATCH_SIZE = 32
MAX_LEN = 49
model_max_seq=128
max_epoch = 4
num_heads = 2

dataset = TranslationDataset(text_pairs, vocab, MAX_LEN)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
# define a real gpt:
from BuildingBlocks import MultiHeadAttention

# gpt config:
GPT_CONFIG_124M = {
"vocab_size": len(vocab), # Vocabulary size
"context_length": 128, # Context length: max sequence length the model can handle 
"emb_dim": 64, # Embedding dimension
"n_heads": 4, # Number of attention heads
"n_layers": 4, # Number of layers
"drop_rate": 0.1, # Dropout rate
"qkv_bias": False # Query-Key-Value bias
}

class LayerNorm(nn.Module):
    def __init__(self, emb_dim):
        super().__init__()
        self.eps = 1e-5
        self.scale = nn.Parameter(torch.ones(emb_dim))
        self.shift = nn.Parameter(torch.zeros(emb_dim))

    def forward(self, x):
        mean = x.mean(dim = -1, keepdim = True)
        # unbiased=False: divided by n instead of n-1
        var = x.var(dim = -1, keepdim = True, unbiased = False)
        norm_x = (x-mean) / torch.sqrt(var + self.eps)
        return self.scale * norm_x + self.shift
    
class GELU(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self, x):
        return 0.5*x*(1+torch.tanh(
            torch.sqrt(torch.tensor(2.0 / torch.pi)) * (x + 0.044715 *torch.pow(x, 3))
        ))
    
class FeedForward(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.layers = nn.Sequential(
            # (2, 3, 768)->(2, 3, 3072)
            nn.Linear(cfg["emb_dim"], 4*cfg["emb_dim"]),
            # (2,3,3072) -> (2,3,3072)
            GELU(),
            # (2,3,3072)->(2,3,768)
            nn.Linear(4*cfg["emb_dim"], cfg["emb_dim"]),
        )
    def forward(self, x):
        return self.layers(x)
    
class TransformerBlock(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.att = MultiHeadAttention(
            d_in = cfg["emb_dim"],
            d_out = cfg["emb_dim"],
            context_length=cfg["context_length"],
            num_heads = cfg["n_heads"],
            dropout = cfg["drop_rate"],
            qkv_bias = cfg["qkv_bias"])
        self.ff = FeedForward(cfg)
        self.norm1 = LayerNorm(cfg["emb_dim"])
        self.norm2 = LayerNorm(cfg["emb_dim"])
        self.drop_shortcut = nn.Dropout(cfg["drop_rate"])
    def forward(self, x):

        shortcut = x
        x = self.norm1(x)
        x = self.att(x)
        x = self.drop_shortcut(x)
        x = x + shortcut

        shortcut = x
        x = self.norm2(x)
        x = self.ff(x)
        x = self.drop_shortcut(x)
        x = x + shortcut
        return x
    
# GPT DEF
class GPTModel(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.tok_emb = nn.Embedding(cfg["vocab_size"], cfg["emb_dim"])
        self.pos_emb = nn.Embedding(cfg["context_length"], cfg["emb_dim"])
        self.drop_emb = nn.Dropout(cfg["drop_rate"])

        self.trf_blocks = nn.Sequential(
            *[TransformerBlock(cfg) for _ in range(cfg["n_layers"])])
        self.final_norm = LayerNorm(cfg["emb_dim"])
        self.out_head = nn.Linear(
            cfg["emb_dim"], cfg["vocab_size"], bias = False
        )

    def forward(self, in_idx):
        batch_size, seq_len = in_idx.shape
        tok_embeds = self.tok_emb(in_idx)
        pos_embeds = self.pos_emb(
            torch.arange(seq_len, device = in_idx.device)
        )

        x = tok_embeds + pos_embeds
        x = self.drop_emb(x)
        x = self.trf_blocks(x)
        x = self.final_norm(x)
        logits = self.out_head(x)
        return logits

# %%
import time

# %%
# initialize model and start training

# model = SimpleGPTTranslator(vocab_size=vocab_size).to(device)
model = GPTModel(GPT_CONFIG_124M).to(device)

K = torch.cuda.device_count()

if K > 1:
    print(f'======= training in {K} GPUs =======')
    model = DataParallel(model, device_ids = list(range(K)))
    

optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# criterion = nn.CrossEntropyLoss(ignore_index=vocab["<pad>"])
criterion = nn.CrossEntropyLoss(ignore_index = -100)
ignore_index = [0] # ignore <pad>


# training loop cn-eng:
for epoch in range(max_epoch):
    total_loss = 0
    start = time.time()
    for src, tgt in dataloader:
        
        src = src.to(device)
        tgt = tgt.to(device)
        # print(tgt)
        msk = torch.isin(tgt, torch.tensor(ignore_index).to(device))
        tgt[msk] = -100
        # print(tgt)
        # print(src.shape)
        optimizer.zero_grad()
        # print(src)
        
        output = model(src)
        # output = model_dp(src)
        
        # print(output.shape)
        loss = criterion(output.view(-1, vocab_size), tgt.view(-1))
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    end = time.time()
    print(f"Epoch {epoch+1}, Loss: {total_loss/len(dataloader):.4f}, Time: {end-start:.4f}s")

# # training loop reverse: eng-cn
# for epoch in range(max_epoch):
#     total_loss = 0
#     for src, tgt in dataloaderreverse:
#         src = src.to(device)
#         tgt = tgt.to(device)
#         # print(tgt)
#         msk = torch.isin(tgt, torch.tensor(ignore_index).to(device))
#         tgt[msk] = -100
#         # print(tgt)
#         # print(src.shape)
#         optimizer.zero_grad()
#         # print(src)
#         output = model(src)
#         # print(output.shape)
#         loss = criterion(output.view(-1, vocab_size), tgt.view(-1))
#         loss.backward()
#         optimizer.step()
#         total_loss += loss.item()
#     print(f"Epoch {epoch+1}, Loss: {total_loss/len(dataloader):.4f}")

# save model
# Out:
# ======= training in 2 GPUs =======
# Epoch 1, Loss: 5.3646, Time: 33.9067s
# Epoch 2, Loss: 4.4118, Time: 32.6374s
# Epoch 3, Loss: 4.0451, Time: 31.4249s
# Epoch 4, Loss: 3.7969, Time: 31.3872s

# %%
# save model
torch.save(model.module.state_dict(), "gpt2_rev_weights.pth")

# %%
# reload model
# model = SimpleGPTTranslator(vocab_size=vocab_size).to(device)
model = GPTModel(GPT_CONFIG_124M).to(device)
model = DataParallel(model, device_ids = list(range(K)))
model.module.load_state_dict(torch.load('gpt2_rev_weights.pth', map_location=device, weights_only=True))
# model.load_state_dict(torch.load('gpt2_weights.pth', map_location=device))
# Out:
# <All keys matched successfully>

# %%
# translate chinese to english
def translate_cn_eng(model, ch_text, vocab, max_len=80):
    model.to(device)
    model.eval()

    input_ids = (
        [vocab["<sos>"]] +
        text_to_ids(ch_text, vocab) +
        [vocab["<sep>"]]
    )
    input_tensor = torch.tensor([input_ids], device=device)


    for _ in range(max_len):
        if len(input_ids) >50:
            # print('max length hit')
            break
        output = model(input_tensor)

        # extract the last words of output as the predicted words
        # [0, -1]: 0 for batch, since we only have 1 data per batch
        next_token = output[0, -1].argmax().item()
        # print(next_token)
        input_ids.append(next_token)
        if next_token == vocab["<eos>"]:
            print('predict ends')
            break
        

        input_tensor = torch.tensor([input_ids], device=device)
    

    sep_pos = input_ids.index(vocab["<sep>"])
    en_ids = input_ids[sep_pos+1:-1]
    

    id_to_token = {v: k for k, v in vocab.items()}
    return " ".join([id_to_token[id] for id in en_ids])


# translate english to chinese (deprecated)
def translate_eng_cn(model, eng_text, vocab, max_len=80):
    model.to(device)
    model.eval()

    input_ids = (
        [vocab["<sos>"]] +
        text_to_ids(eng_text, vocab) +
        [vocab["<sep>"]]
    )
    input_tensor = torch.tensor([input_ids], device=device)
    # print(input_tensor.device)
    # input_tensor = input_tensor.to(device)
    

    for _ in range(max_len):
        if len(input_ids) >50:
            # print('max length hit')
            break
        output = model(input_tensor)

        # extract the last words of output as the predicted words
        # [0, -1]: 0 for batch, since we only have 1 data per batch
        next_token = output[0, -1].argmax().item()
        # print(next_token)
        input_ids.append(next_token)
        if next_token == vocab["<eos>"]:
            print('predict ends')
            break
        

        input_tensor = torch.tensor([input_ids], device=device)
    

    sep_pos = input_ids.index(vocab["<sep>"])
    ch_ids = input_ids[sep_pos+1:-1]
    

    id_to_token = {v: k for k, v in vocab.items()}
    return "".join([id_to_token[id] for id in ch_ids])

# %%
translate_cn_eng(model, '牛', vocab)
# Out:
# predict ends
# 'the piano'

# %%
# eval
# chinese to english
import numpy as np
for i in np.random.randint(0, len(text_pairs), eval_num):
    cn = text_pairs[i][0]
    en = text_pairs[i][1]
    print(f'> {cn}')
    print(f'= {en}')
    print(f'< {translate_cn_eng(model, cn, vocab)}')
    print('='*20)
# Out:
# > 您不必感谢我。
# = Don't mention it.
# predict ends
# < you dont have to me
# ====================
# > 湯姆還沒有失去信心。
# = Tom hasn't lost his confidence.
# predict ends
# < tom didnt have to go to learn
# ====================
# > 我記得在哪兒見過她。
# = I remember seeing her somewhere.
# predict ends
# < i have a letter in her
# ====================
# > 我要你放鬆一下。
# = I want you to relax.
# predict ends
# < i want you to see you
# ====================
# > 他們兩個人都在房間裡。
# = Both of them are in the room.
# predict ends
# < they were in the room
# ====================
# > 我喜歡咖啡勝過茶。
# = I like coffee better than tea.
# predict ends
# < i like to play tennis
# ====================
# > 你看上去不太好。
# = You don't look very good.
# predict ends
# < you dont have a good idea
# ====================
# > 他有能力比我做得更好。
# = He can do it better than I can.
# predict ends
# < he may have any friends
# ====================
# > 我從廣播中聽到它。
# = I heard it on the radio.
# predict ends
# < i was able to see the problem
# ====================
# > 我決定買一輛車。
# = I decided to buy a car.
# predict ends
# < i think a car is tired of the car
# ====================
# > 人们仍然认为汤姆说谎。
# = People still think Tom is a liar.
# predict ends
# < people think tom is sure that mary
# ====================
# > 他对吗？
# = Is he correct?
# predict ends
# < he is he
# ====================
# > 她一直哭哭啼啼。
# = She did nothing but cry all the while.
# predict ends
# < she has a lot of the bank
# ====================
# > 我不想让汤姆死。
# = I don't want Tom to die.
# predict ends
# < i dont want tom
# ====================
# > 在这种情况下，形容词放在名词前面。
# = In this case, the adjective goes before the noun.
# predict ends
# < the train is on the street in the world
# ====================
# > 汤姆穿着鞋睡了。
# = Tom slept with his shoes on.
# predict ends
# < tom was sitting to the bus
# ====================
# > 我不能走。
# = I can't leave.
# predict ends
# < i dont go
# ====================
# > 電梯在哪裡？
# = Where is the elevator?
# predict ends
# < wheres the door
# ====================
# > 從他大學畢業以後, 他教了兩年的英語。
# = After he had graduated from the university, he taught English for two years.
# predict ends
# < he gave his wife his wife
# ====================
# > 为什么你昨晚睡不着？
# = Why couldn't you sleep last night?
# predict ends
# < why dont you please wait for you
# ====================
# > 我运气很好。
# = I got lucky.
# predict ends
# < i love a good idea
# ====================
# > 看看桌上的那張相片。
# = Look at that picture on the desk.
# predict ends
# < please turn off the desk
# ====================
# > 他們的相遇是必然的。
# = Their meeting was inevitable.
# predict ends
# < they must be able to say
# ====================
# > 那只黑鸟不是乌鸫。
# = That black bird is not a blackbird.
# predict ends
# < that isnt not a bad of the world
# ====================
# > 你最好不要在這裡等。
# = You'd better not wait here.
# predict ends
# < you dont have to go there
# ====================
# > 钱币的价值取决于所使用的金属的重量。
# = The value of the coins depended on the weight of the metal used.
# predict ends
# < the population is made the teacher is a teacher
# ====================
# > 動物園裡有很多動物嗎？
# = Are there many animals in the zoo?
# predict ends
# < is there any of the world
# ====================
# > 我昨晚睡得晚。
# = I stayed up late last night.
# predict ends
# < i have to wait tomorrow
# ====================
# > 你有口臭。
# = You have bad breath.
# predict ends
# < you have a cup
# ====================
# > 這個十字路口很危險。
# = This intersection is dangerous.
# predict ends
# < this sentence is very expensive
# ====================
# > 湯姆說我絕不該做。
# = Tom told me that I shouldn't ever do that.
# predict ends
# < tom doesnt want to do that
# ====================
# > 让我一个人待着。
# = Leave me alone.
# predict ends
# < i think a bit of my brother
# ====================
# > 把我們想知道的都說說。
# = Now tell us what we want to know.
# predict ends
# < lets know the truth i want to know the truth
# ====================
# > 昨天他帶我去公園。
# = He took me to the park yesterday.
# predict ends
# < he went to go home yesterday
# ====================
# > 他的母親是一名學校老師。
# = His mother was a school teacher.
# predict ends
# < his father is a student
# ====================
# > 我載她去城裡了。
# = I gave her a lift to town.
# predict ends
# < i went to her
# ====================
# > 湯姆瞥了墻上的錶一眼。
# = Tom glanced at the clock on the wall.
# predict ends
# < tom has a ball
# ====================
# > 可能你工作得太拼命？
# = Maybe you're working too hard.
# predict ends
# < you can have a good idea
# ====================
# > 回家吧。
# = Go home.
# predict ends
# < go home
# ====================
# > 我去那裡很多次了。
# = I went there many times.
# predict ends
# < i went there in this morning
# ====================
# > 是时候离开了。
# = It was time to leave.
# predict ends
# < the door is the next time
# ====================
# > 你们永远不会一个人的。
# = You'll never be alone.
# predict ends
# < you dont have any friends
# ====================
# > 警察抓了正在跑的那個男人。
# = The policeman captured the man who was running.
# predict ends
# < the man is in the world
# ====================
# > 我一整天都在看这本小说。
# = I spent the whole day reading that novel.
# predict ends
# < i have a book for the book
# ====================
# > 她有一颗纯洁的心。
# = She has a pure heart.
# predict ends
# < she has a dog
# ====================
# > 我把咖啡倒翻在地毯上了。
# = I spilled my coffee on the carpet.
# predict ends
# < i bought a new car in the train
# ====================
# > 這首曲子叫什麼名字？
# = What's the name of this tune?
# predict ends
# < whats the bus
# ====================
# > 我請他幫忙。
# = I asked him for a favor.
# predict ends
# < i think he was tired
# ====================
# > 她总是在班上拿倒数第一。
# = She is always at the bottom of the class.
# predict ends
# < she is a student in the hospital
# ====================
# > 我們必須做點甚麼。
# = We must do something.
# predict ends
# < we must do anything
# ====================
# > 湯姆哭了很長時間。
# = Tom cried for a long time.
# predict ends
# < tom has a lot of coffee
# ====================
# > 我們的友情會長久留存。
# = Our friendship will last a long time.
# predict ends
# < our team can we come
# ====================
# > 这与你有直接关系。
# = This directly concerns you.
# predict ends
# < this book is you sure
# ====================
# > 你可能不記得我了，但我記得你。
# = You may not remember me, but I remember you.
# predict ends
# < you may i think you do you think i can do you
# ====================
# > 我知道這天要來。
# = I knew this day was coming.
# predict ends
# < i know this book
# ====================
# > 很多人都参加了他的葬礼。
# = Many attended his funeral.
# predict ends
# < the man has a beautiful of his wife
# ====================
# > 你找到你的票了嗎？
# = Have you found your ticket yet?
# predict ends
# < did you show your name
# ====================
# > 我今天可以借用你的汽车吗?
# = May I use your car today?
# predict ends
# < may i use your car
# ====================
# > 外面起霧了。
# = It's foggy out.
# predict ends
# < the dog is full
# ====================
# > 走廊裡有一部電話。
# = There's a telephone in the hall.
# predict ends
# < there is there in the door
# ====================
# > 尽管政府拒绝承认，它的经济政策还是失败了。
# = Although the government refuses to admit it, its economic policy is in ruins.
# predict ends
# < the sun was not always never is not to be late
# ====================
# > 我吃了一個蘋果。
# = I've eaten one apple.
# predict ends
# < i have a bath
# ====================
# > 我兩天前感冒了。
# = I caught a cold two days ago.
# predict ends
# < i bought a day
# ====================
# > 他被你迷住了。
# = He's crazy about you.
# predict ends
# < he was able to see you
# ====================
# > 我们必须快点定下旅游日期。
# = We have to fix the date for our trip quickly.
# predict ends
# < we must go to go to the train
# ====================
# > 那女孩不管到哪兒都跟著母親。
# = The girl was always following her mother.
# predict ends
# < that boy cant be able to the boy
# ====================
# > 骄傲使人落后。
# = Pride goes before a fall.
# predict ends
# < the dog was filled
# ====================
# > 你不吃沒關係。
# = It's OK not to eat it.
# predict ends
# < you dont have any chance
# ====================
# > 我今天要准备晚饭。
# = I have to cook dinner today.
# predict ends
# < i have to go to the morning
# ====================
# > 我們正要離開的時候下雨了。
# = We were just about to leave when it started to rain.
# predict ends
# < we had to go to go to go out
# ====================
# > 這次不一樣。
# = This time it's different.
# predict ends
# < this isnt a good
# ====================
# > 牙齿卡了点东西。
# = You have something stuck in your teeth.
# predict ends
# < the sun is full of the airport
# ====================
# > 他很忙。
# = He was busy.
# predict ends
# < he is very happy
# ====================
# > 他解释事故是怎么发生的。
# = He explained how the accident came about.
# predict ends
# < he is the reason of the reason
# ====================
# > 我們只是需要個計畫。
# = We just need a plan.
# predict ends
# < we need to know
# ====================
# > 把你的書閤起來看著我。
# = Look at me with your books closed.
# predict ends
# < give me your book
# ====================
# > 这块地毯是手工制作的。
# = This rug is handmade.
# predict ends
# < this is the boy is the most of the best
# ====================
# > 汤姆把他的汽车卖给了玛丽。
# = Tom sold Mary his car.
# predict ends
# < tom said his car to marys car
# ====================
# > 我聽湯姆說話聽得煩。
# = I'm tired of listening to Tom.
# predict ends
# < i think tom said that mary was tired
# ====================
# > 她正吃著一個蘋果。
# = She's eating an apple.
# predict ends
# < she has been sick
# ====================
# > 那样说得通。
# = It makes sense.
# predict ends
# < that is not important
# ====================
# > 我會等到四點。
# = I'll wait till four o'clock.
# predict ends
# < ill wait for a walk
# ====================
# > 你吃過午飯了嗎？
# = Have you eaten your lunch yet?
# predict ends
# < did you eat lunch
# ====================
# > 他抓住了绳子。
# = He caught hold of the rope.
# predict ends
# < he was wearing a ball
# ====================
# > 她18岁的时候来到东京。
# = She came to Tokyo when she was 18.
# predict ends
# < she was going to go to the airport
# ====================
# > 她把我哥哥誤認為我。
# = She mistook my brother for me.
# predict ends
# < she gave me her my brother
# ====================
# > 我坐地鐵上學。
# = I go to school by subway.
# predict ends
# < i have to go to school
# ====================
# > 这应证了我的想法。
# = That thought crossed my mind.
# predict ends
# < the problem is my opinion
# ====================
# > 我同意你這一點。
# = I agree with you on this point.
# predict ends
# < i have a bit of you
# ====================
# > 体育无国界。
# = Sport knows no borders.
# predict ends
# < the sun is very important
# ====================
# > 這本小冊子是免費的。
# = This booklet is free of charge.
# predict ends
# < this is the boy
# ====================
# > 他不會說我們的語言。
# = He doesn't speak our language.
# predict ends
# < he cant speak french
# ====================
# > 你对这件事有什么看法？
# = What is your opinion on this matter?
# predict ends
# < what do you know what to do
# ====================
# > 我們能把門鎖上嗎？
# = Can we lock this door?
# predict ends
# < can we see the door
# ====================
# > 一個美麗的女人坐在我前面一排。
# = A beautiful woman was seated one row in front of me.
# predict ends
# < a ball is going to my brother in my brother
# ====================
# > 六岁及以上的小孩应该上学。
# = Children of six and above should attend school.
# predict ends
# < the boy will be on the children
# ====================
# > 学法语不难。
# = Learning French isn't difficult.
# predict ends
# < the dog is not easy
# ====================
# > 软件正在不断进化。
# = Software is constantly evolving.
# predict ends
# < the sun is not to the world
# ====================
# > 我對他的問題感到非常困惑。
# = I was awfully confused by his question.
# predict ends
# < i have a good job
# ====================
# > 我們計劃去爬那座山。
# = We plan to climb that mountain.
# predict ends
# < we must go to the world
# ====================

# %%
# # english to chinese
# import numpy as np
# for i in np.random.randint(0, len(text_pairs), eval_num):
#     cn = text_pairs[i][0]
#     en = text_pairs[i][1]
#     print(f'> {en}')
#     print(f'= {cn}')
#     print(f'< {translate_eng_cn(model, en, vocab)}')
#     print('='*20)
